# %%
#pip install bash_kernel

# %%
import re
import pandas as pd
import os
import glob
from datetime import datetime

# %% [markdown]
# ## Data preprocessing for the citation rate prediction

# %% [markdown]
# Data can be found at https://snap.stanford.edu/data/cit-HepTh.html
#
# It represents the citation network in the fields of high energy theoretical physics

# %% [markdown]
# Let`s download the data and unzip it

# %%
# %%bash
# cd ..
# mkdir data
# cd data
# wget https://snap.stanford.edu/data/cit-HepTh.txt.gz
# wget https://snap.stanford.edu/data/cit-HepTh-dates.txt.gz
# wget https://snap.stanford.edu/data/cit-HepTh-abstracts.tar.gz
# gzip -d cit-HepTh.txt.gz
# gzip -d cit-HepTh-dates.txt.gz
# gzip -d cit-HepTh-abstracts.tar.gz
# tar -xf cit-HepTh-abstracts.tar
# Out:
# --2024-11-06 22:09:18--  https://snap.stanford.edu/data/cit-HepTh.txt.gz
# Resolving snap.stanford.edu (snap.stanford.edu)... 171.64.75.80
# Connecting to snap.stanford.edu (snap.stanford.edu)|171.64.75.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1317497 (1,3M) [application/x-gzip]
# Saving to: ‘cit-HepTh.txt.gz’
#
#      0K .......... .......... .......... .......... ..........  3% 80,8K 15s
#     50K .......... .......... .......... .......... ..........  7%  271K 10s
#    100K .......... .......... .......... .......... .......... 11%  300K 7s
#    150K .......... .......... .......... .......... .......... 15% 6,14M 5s
#    200K .......... .......... .......... .......... .......... 19% 10,3M 4s
#    250K .......... .......... .......... .......... .......... 23%  287K 4s
#    300K .......... .......... .......... .......... .......... 27% 44,4M 3s
#    350K .......... .......... .......... .......... .......... 31% 10,6M 3s
#    400K .......... .......... .......... .......... .......... 34% 5,10M 2s
#    450K .......... .......... .......... .......... .......... 38% 12,2M 2s
#    500K .......... .......... .......... .......... .......... 42%  192K 2s
#    550K .......... .......... .......... .......... .......... 46% 11,9M 2s
#    600K .......... .......... .......... .......... .......... 50% 7,76M 1s
#    650K .......... .......... .......... .......... .......... 54% 8,95M 1s
#    700K .......... .......... .......... .......... .......... 58% 7,31M 1s
#    750K .......... .......... .......... .......... .......... 62% 6,22M 1s
#    800K .......... .......... .......... .......... .......... 66% 11,8M 1s
#    850K .......... .......... .......... .......... .......... 69%  148K 1s
#    900K .......... .......... .......... .......... .......... 73% 96,3M 1s
#    950K .......... .......... .......... .......... .......... 77% 3,73M 1s
#   1000K .......... .......... .......... .......... .......... 81% 26,2M 0s
#   1050K .......... .......... .......... .......... .......... 85%  219M 0s
#   1100K .......... .......... .......... .......... .......... 89%  242M 0s
#   1150K .......... .......... .......... .......... .......... 93%  250M 0s
#   1200K .......... .......... .......... .......... .......... 97%  190M 0s
#   1250K .......... .......... .......... ......               100%  144M=1,8s
#
# 2024-11-06 22:09:21 (705 KB/s) - ‘cit-HepTh.txt.gz’ saved [1317497/1317497]
#
# --2024-11-06 22:09:21--  https://snap.stanford.edu/data/cit-HepTh-dates.txt.gz
# Resolving snap.stanford.edu (snap.stanford.edu)... 171.64.75.80
# Connecting to snap.stanford.edu (snap.stanford.edu)|171.64.75.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length:
# 2024-11-06 22:09:36 (977 KB/s) - ‘cit-HepTh-abstracts.tar.gz’ saved [11956788/11956788]

# %% [markdown]
# The following script will remove unnecessary lines from the files, and unfolder the folders with data

# %%
# %%bash
# cd data
# sed '1,4d' cit-HepTh.txt > temp.txt && mv temp.txt cit-HepTh.txt
# sed '1d' cit-HepTh-dates.txt > temp.txt && mv temp.txt cit-HepTh-dates.txt
# mv cit-HepTh.txt edgelist.txt
# mv cit-HepTh-dates.txt dates.txt

# %%
# %%bash
# cd data
# mkdir -p meta_files
#
# for folder in *; do
#   if [ -d "$folder" ] && [ "$folder" != "meta_files" ]; then
#     mv "$folder"/*.* meta_files/
#   fi
# done
#
# find . -type d -empty -not -path "./meta_files" -delete

# %% [markdown]
# Parsing the metadata files. We consider all other information to be too sparse or irrelevant for the research

# %%
paper_features = ('Paper','Date','Title','Authors','Abstract')

# %%
def data_dict_from_file(filename):
    data_dict = dict()
    with open(filename, 'r') as file:
        text = file.read()

        last_comment = text.split("\\\\")[2].strip()

        # Extract key-value pairs using regular expressions and split by newline
        pattern = r"(\S+): (.+)"
        matches = re.findall(pattern, text.split("\\\\")[1], re.MULTILINE)

        # Create a dictionary from the matches
        data_dict = {key.strip(): value.strip() for key, value in matches}
        to_pop = list()
        for key in data_dict.keys():
            if key not in paper_features:
                to_pop.append(key)
        for key in to_pop:
            data_dict.pop(key, None)
        data_dict['Abstract'] = last_comment
        data_dict['Paper'] = int(data_dict['Paper'][7:])
        
        return data_dict

# %%
dict_list = list()

# %%
directory = os.path.join(os.pardir, 'data', 'meta_files')
files = glob.glob(os.path.join(directory, '*'))

for file in files:
    if os.path.isfile(file):
        new_dict = data_dict_from_file(file)
        dict_list.append(new_dict)

# %%
full_data_dictionary = dict()
for feature in paper_features:
    full_data_dictionary[feature] = []

# %%
for d in dict_list:
    for key in paper_features:
        if key not in d.keys():
            d[key] = ''
        full_data_dictionary[key].append(d[key])

# %% [markdown]
# Creating dataframe with everything we need (dates still need some manipulation)

# %%
df = pd.DataFrame.from_dict(full_data_dictionary)
df.head()
# Out:
#      Paper                                           Date  \
# 0  9511170  Thu, 23 Nov 1995 15:22:03 +0000 (GMT)   (8kb)
# 1  9211024            Wed, 4 Nov 1992 14:49 +0200   (7kb)
# 2  9806180         Sun, 21 Jun 1998 21:09:27 GMT   (11kb)
# 3   108199         Mon, 27 Aug 2001 16:34:58 GMT   (10kb)
# 4   110123          Mon, 15 Oct 2001 05:40:51 GMT   (5kb)
#
#                                                Title  \
# 0  Einstein-Infeld-Hoffman method and soliton dyn...
# 1  Discretization of the Superparticle Path Integral
# 2                      Comments on N=2 AdS Orbifolds
# 3  Determinant Line Bundles and Topological Invar...
# 4  Entropy of the three dimensional Schwarzschild...
#
#                                              Authors  \
# 0                                    Jacek Dziarmaga
# 1        J. Grundberg, U. Lindstrom and H. Nordstrom
# 2                                       Sergei Gukov
# 3  A.A. Bytsenko, M.C. Falleiros, A.E. Goncalves ...
# 4
#
#                                             Abstract
# 0  We consider slow motion of a pointlike topolog...
# 1  Requiring that the path integral has the globa...
# 2  We discuss twisted states of AdS orbifolds whi...
# 3  We give some remarks on twisted determinant li...
# 4  We study the three dimensional Schwarzschild-d...

# %% [markdown]
# Let`s fix the dates

# %%
def is_date_format(date_str,form):
    pattern = r'^\d{2}-[A-Z]{3}-\d{4}$'
    if form == 2:
        pattern = r'^\d{2}/\d{2}/\d{2}$'
    if form == 3:
        pattern = r'^(0?\d|[12]\d|3[01])-[a-zA-Z]{3}-\d{4}$'
    if re.match(pattern, date_str):
        return True
    else:
        return False

# %%
for i, row in df.iterrows():
    
    if (row['Paper'] == 9509068):  # no year specified, add it manually
        df.at[i,'Date'] = "2000-09-13"
        continue
        
    date_str = row['Date']
    date_str = date_str.split()
    date_obj = None
    
    if is_date_format(date_str[0],1):
        sp = date_str[0].split('-')
        date_conc = sp[0] + " " + sp[1] + " " + sp[2]
        date_obj = datetime.strptime(date_conc, "%d %b %Y")
        
    elif is_date_format(date_str[0],2): 
        date_obj = datetime.strptime(date_str[0], "%m/%d/%y")
    
    elif is_date_format(date_str[0],3):
        sp = date_str[0].split('-')
        date_conc = '0' + sp[0] + " " + sp[1] + " " + sp[2]
        date_obj = datetime.strptime(date_conc, "%d %b %Y")
    else:
        date_str = date_str[(1 - date_str[0][0].isdigit()):]

        if not date_str[0].isdigit():
            tmp = date_str[0]
            date_str[0] = date_str[1]
            date_str[1] = tmp

        ind = 2
        if date_str[2][-1] == ',':
            date_str[2] = date_str[2][:-1]
        while not date_str[2].isdigit():
            ind += 1
            date_str[2] = date_str[ind]
        if int(date_str[2]) < 100:

            date_str[2] = '19' + date_str[2]

        date_str[1] = date_str[1][:3].upper()
        date_only = date_str[0] +" "+ date_str[1] +" "+ date_str[2]
        date_obj = datetime.strptime(date_only, "%d %b %Y")
        
    formatted_date = date_obj.strftime("%Y-%m-%d")
    df.at[i,'Date'] = formatted_date

# %% [markdown]
# Now let`s turn Authors into a list

# %%
for i, row in df.iterrows():
    string = row['Authors']
    string = string.replace('and',',').replace(' ','').split(',')
    df.at[i,'Authors'] = string

# %% [markdown]
# Also let`s rename columns properly, check our df, and output the result

# %%
df = df.rename(columns={"Paper": "Paper_ID"})

# %%
df.head()
# Out:
#    Paper_ID        Date                                              Title  \
# 0   9511170  1995-11-23  Einstein-Infeld-Hoffman method and soliton dyn...
# 1   9211024  1992-11-04  Discretization of the Superparticle Path Integral
# 2   9806180  1998-06-21                      Comments on N=2 AdS Orbifolds
# 3    108199  2001-08-27  Determinant Line Bundles and Topological Invar...
# 4    110123  2001-10-15  Entropy of the three dimensional Schwarzschild...
#
#                                              Authors  \
# 0                                   [JacekDziarmaga]
# 1            [J.Grundberg, U.Lindstrom, H.Nordstrom]
# 2                                      [SergeiGukov]
# 3  [A.A.Bytsenko, M.C.Falleiros, A.E.Goncalves, Z...
# 4                                                 []
#
#                                             Abstract
# 0  We consider slow motion of a pointlike topolog...
# 1  Requiring that the path integral has the globa...
# 2  We discuss twisted states of AdS orbifolds whi...
# 3  We give some remarks on twisted determinant li...
# 4  We study the three dimensional Schwarzschild-d...

# %%
df.to_csv(os.path.join(os.pardir, "data", "processed.csv"))

# %% [markdown]
# We didn`t need dates file yet, but that time may come

# %% [markdown]
# We noticed that the graph has some incorrect edges: some papers cited other papers that did not yet exist at that time. Let's iterate over all the edges and delete the bad ones.

# %%
import networkx as nx
from get_graph import get_digraph

# %%
G: nx.DiGraph = get_digraph()

# %%
G.number_of_nodes(), G.number_of_edges()
# Out:
# (27770, 352807)

# %%
G.nodes()
# Out:
# NodeView((1001, 9304045, 9308122, 9309097, 9311042, 9401139, 9404151, 9407087, 9408099, 9501030, 9503124, 9504090, 9504145, 9505025, 9505054, 9505105, 9505162, 9506048, 9506112, 9506144, 9507050, 9507158, 9508094, 9508155, 9510142, 9510225, 9510234, 9511030, 9511171, 9601108, 9602022, 9602114, 9603003, 9603150, 9603161, 9603167, 9605184, 9605222, 9606017, 9606040, 9607163, 9607207, 9608086, 9609070, 9609071, 9609239, 9611137, 9612108, 9701162, 9702094, 9702155, 9702198, 9703082, 9703166, 9704097, 9705030, 9705044, 9705104, 9705220, 9706005, 9707014, 9707042, 9707049, 9710230, 9711036, 9711104, 9712028, 9712042, 9802194, 9805056, 9805206, 9806094, 9810188, 9811217, 9905036, 9907041, 9908007, 9908144, 9909108, 9909120, 9909229, 9910238, 9910248, 9910268, 9204040, 9203084, 9204035, 9205041, 9207049, 9207111, 9301042, 9301043, 9201015, 9201040, 9201047, 9202046, 9202059, 9202092, 9203008, 9203031, 9204037, 9204046, 9205046, 9205060, 9205062, 9205068, 9206023, 9206051, 9206078, 9207016, 9208076, 9209052, 9210015, 9210021, 9210121, 9211021, 9211041, 9212089, 9301005, 9302033, 9302069, 9302126, 9303032, 9304155, 9305185, 9308042, 9305139, 9309140, 9204102, 9211097, 9402002, 9402005, 9402044, 9403195, 9403198, 9406128, 9205081, 9207053, 9208055, 9209016, 9211056, 9303057, 9305142, 9306052, 9306125, 9311120, 9402032, 9406105, 9406198, 9407021, 9407111, 9408040, 9408074, 9408083, 9409021, 9410167, 9410210, 9412184, 9205027, 9406012, 9411149, 9411178, 9201059, 9309152, 9310067, 9412115, 9501068, 9502072, 9504027, 9504047, 9304154, 9501022, 9502057, 9503179, 9308083, 9411048, 9411057, 9501111, 9502077, 9503163, 9504006, 9504034, 9505023, 9505053, 9505062, 9302103, 9305069, 9406032, 9409188, 9406055, 9408036, 9411234, 9412200, 9506075, 9506091, 9506024, 9506077, 9506110, 9506160, 9506194, 9507027, 9207060, 9503212, 9506126, 9506150, 9507048, 9303106, 9410073, 9411187, 9504081, 9504095, 9506057, 9507090, 9508056, 9304135, 9412209, 9505073, 9505150, 9506084, 9506102, 9507113, 9507115, 9507121, 9507151, 9507153, 9507168, 9508044, 9508064, 9508071, 9508096, 9508143, 9508144, 9409110, 9503208, 9507012, 9508154, 9509009, 9510093, 9201056, 9206080, 9301083, 9307158, 9308062, 9407031, 9506122, 9509066, 9510135, 9510169, 9204030, 9205009, 9510017, 9510173, 9510182, 9412236, 9511164, 9511222, 9512016, 9512017, 9512059, 9512145, 9601014, 9601038, 9206101, 9409111, 9505183, 9506101, 9510086, 9510161, 9510209, 9511080, 9512077, 9512181, 9512196, 9512219, 9601036, 9602010, 9210127, 9304104, 9506156, 9508107, 9509106, 9512129, 9512178, 9602049, 9602064, 9602097, 9602118, 9512053, 9602030, 9602070, 9602098, 9602120, 9404060, 9511108, 9511157, 9602102, 9603037, 9511204, 9512078, 9509151, 9511026, 9511088, 9601029, 9601162, 9602052, 9603142, 9309110, 9403054, 9406090, 9412117, 9502012, 9510055, 9605036, 9603081, 9603127, 9604198, 9605150, 9605199, 9406178, 9510227, 9512062, 9603042, 9602167, 9509132, 9608039, 9608079, 9604097, 9605154, 9608111, 9605131, 9605200, 9606044, 9606086, 9607020, 9607139, 9608024, 9608047, 9608109, 9509042, 9509161, 9510106, 9602051, 9603108, 9608194, 9511077, 9512226, 9603170, 9604034, 9609161, 9604129, 9606165, 9610111, 9602065, 9604030, 9605053, 9606122, 9606148, 9607091, 9607105, 9610195, 9610251, 9611090, 9612052, 9701015, 9701023, 9701147, 9503115, 9505006, 9505075, 9505082, 9505100, 9506098, 9507013, 9507018, 9507032, 9507169, 9510148, 9510228, 9511154, 9603086, 9603136, 9603158, 9607076, 9607202, 9610132, 9611190, 9611197, 9612114, 9612207, 9204060, 9205004, 9304026, 9509049, 9511230, 9606112, 9606008, 9609219, 9207091, 9210068, 9504102, 9505097, 9507008, 9509175, 9509176, 9510074, 9511180, 9512005, 9512006, 9512139, 9603004, 9604062, 9605032, 9606043, 9606073, 9607032, 9608183, 9609059, 9611112, 9611188, 9612105, 9505035, 9506011, 9509162, 9510101, 9608085, 9611230, 9612131, 9702014, 9702154, 9509146, 9606133, 9610154, 9701165, 9701175, 9703007, 9703148, 9310035, 9604178, 9606176, 9607019, 9607057, 9607229, 9608053, 961105 ...

# %%
edges_to_remove = [e for e in G.edges if not G.nodes[e[0]]['Date'] > G.nodes[e[1]]['Date']]
G.remove_edges_from(edges_to_remove)

# %%
G.number_of_nodes(), G.number_of_edges()
# Out:
# (27770, 351285)

# %% [markdown]
# We decided to remove all nodes not from the largest weak component (stray nodes), since the vast majority of nodes are in the same component

# %%
largest_weak_component = max(nx.weakly_connected_components(G), key=len)
G: nx.DiGraph = G.subgraph(largest_weak_component)

# %%
G.number_of_nodes(), G.number_of_edges()
# Out:
# (27376, 351025)

# %%
with open(os.path.join(os.pardir, 'data', 'edgelist.txt'), 'wb') as edgelist_file:
    nx.write_edgelist(G, edgelist_file, data=False)

# %% [markdown]
# Sinse we decided to remove stray nodes let's remove them from dataset too

# %%
df = df[df['Paper_ID'].isin(G.nodes())]
assert df.shape[0] == G.number_of_nodes()
df.to_csv(os.path.join(os.pardir, "data", "processed.csv"), index=False)

# %%
os.remove(os.path.join('data', 'cit-HepTh-abstracts.tar'))
