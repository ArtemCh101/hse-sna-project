# %%
# pip install bash_kernel

# %%
import re
import pandas as pd
import os
import glob
from datetime import datetime
from tqdm import tqdm

# %% [markdown]
# ## Data preprocessing for the citation rate prediction

# %% [markdown]
# Data can be found at https://snap.stanford.edu/data/cit-HepTh.html
#
# It represents the citation network in the fields of high energy theoretical physics

# %% [markdown]
# Let`s download the data and unzip it

# %%
# %%bash
# cd ..
# mkdir data
# cd data
# wget https://snap.stanford.edu/data/cit-HepTh.txt.gz
# wget https://snap.stanford.edu/data/cit-HepTh-dates.txt.gz
# wget https://snap.stanford.edu/data/cit-HepTh-abstracts.tar.gz
# gzip -d cit-HepTh.txt.gz
# gzip -d cit-HepTh-dates.txt.gz
# gzip -d cit-HepTh-abstracts.tar.gz
# tar -xf cit-HepTh-abstracts.tar
# Out:
# --2024-12-01 20:53:13--  https://snap.stanford.edu/data/cit-HepTh.txt.gz
# Resolving snap.stanford.edu (snap.stanford.edu)... 171.64.75.80
# Connecting to snap.stanford.edu (snap.stanford.edu)|171.64.75.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1317497 (1,3M) [application/x-gzip]
# Saving to: ‘cit-HepTh.txt.gz’
#
#      0K .......... .......... .......... .......... ..........  3% 88,8K 14s
#     50K .......... .......... .......... .......... ..........  7%  268K 9s
#    100K .......... .......... .......... .......... .......... 11%  290K 7s
#    150K .......... .......... .......... .......... .......... 15% 1,30M 5s
#    200K .......... .......... .......... .......... .......... 19%  344K 5s
#    250K .......... .......... .......... .......... .......... 23%  283K 4s
#    300K .......... .......... .......... .......... .......... 27%  195K 4s
#    350K .......... .......... .......... .......... .......... 31% 8,84M 3s
#    400K .......... .......... .......... .......... .......... 34%  245K 3s
#    450K .......... .......... .......... .......... .......... 38%  251K 3s
#    500K .......... .......... .......... .......... .......... 42% 11,1M 3s
#    550K .......... .......... .......... .......... .......... 46%  249K 2s
#    600K .......... .......... .......... .......... .......... 50% 10,5M 2s
#    650K .......... .......... .......... .......... .......... 54%  248K 2s
#    700K .......... .......... .......... .......... .......... 58% 12,9M 2s
#    750K .......... .......... .......... .......... .......... 62%  247K 2s
#    800K .......... .......... .......... .......... .......... 66% 8,27M 1s
#    850K .......... .......... .......... .......... .......... 69%  252K 1s
#    900K .......... .......... .......... .......... .......... 73% 27,6M 1s
#    950K .......... .......... .......... .......... .......... 77%  247K 1s
#   1000K .......... .......... .......... .......... .......... 81% 6,32M 1s
#   1050K .......... .......... .......... .......... .......... 85%  294K 1s
#   1100K .......... .......... .......... .......... .......... 89% 8,44M 0s
#   1150K .......... .......... .......... .......... .......... 93% 5,91M 0s
#   1200K .......... .......... .......... .......... .......... 97%  221K 0s
#   1250K .......... .......... .......... ......               100% 27,8K=4,7s
#
# 2024-12-01 20:53:19 (273 KB/s) - ‘cit-HepTh.txt.gz’ saved [1317497/1317497]
#
# --2024-12-01 20:53:19--  https://snap.stanford.edu/data/cit-HepTh-dates.txt.gz
# Resolving snap.stanford.edu (snap.stanford.edu)... 171.64.75.80
# Connecting to snap.stanford.edu (snap.stanford.edu)|171.64.75.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 96569 (94K) [application/x-gzip]
# Saving to: ‘cit-HepTh-dates.txt.gz’
#
#      0K .......... .......... .......... .......... .......... 53% 77,1K 1s
#     50K .......... .......... .......... .......... ....      100%  270M=0,6s
#
# 2024-12-01 20:53:21 (145 KB/s) - ‘cit-HepTh-dates.txt.gz’ saved [96569/96569]
#
# --2024-12-01 20:53:21--  https://snap.stanford.edu/data/cit-HepTh-abstracts.tar.gz
# Resolving snap.stanford.edu (snap.stanford.edu)... 171.64.75.80
# Connecting to snap.stanford.edu (snap.stanford.edu)|171.64.75.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11956788 (11M) [application/x-gzip]
# Saving to: ‘cit-HepTh-abstracts.tar.gz’
#
#      0K .......... .......... .......... .......... ..........  0% 92,6K 2m6s
#     50K .......... .......... .......... .......... ..........  0% 1,49M 66s
#    100K .......... .......... .......... .......... ..........  1%  299K 57s
#    150K .......... .......... .......... .......... ..........  1% 6,94M 43s
#    200K .......... .......... .......... .......... ..........  2%  303K 42s
#    250K .......... .......... .......... .......... ..........  2% 3,55M 35s
#    300K .......... .......... .......... .......... ..........  2% 3,75M 30s
#    350K .......... .......... .......... .......... ..........  3%  237K 32s
#    400K .......... .......... .......... .......... ..........  3% 8,47M 29s
#    450K .......... .......... .......... .......... ..........  4%  255K 30s
#    500K .......... .......... .......... .......... ..........  4% 4,54M 28s
#    550K .......... .......... .......... .......... ..........  5% 12,9M 25s
#    600K .......... .......... .......... .......... ..........  5% 9,00M 23s
#    650K .......... .......... .......... .......... ..........  5%  263K 24s
#    700K .......... .......... .......... .......... ..........  6% 15,0M 23s
#    750K .......... .......... .......... .......... ..........  6% 6,55M 21s
#    800K .......... .......... .......... .......... ..........  7%  251K 23s
#    850K .......... .......... .......... .......... ..........  7%  236K 24s
#    900K .......... .......... .......... .......... ..........  8%  127K 27s
#    950K .......... .......... .......... .......... ..........  8% 42,7M 25s
#   1000K .......... .......... .......... .......... ..........  8%  225M 24s
#   1050K .......... .......... .......... .......... ..........  9%  230M 23s
#   1100K .......... .......... .......... .......... ..........  9%  221M 22s
#   1150K .......... .......... .......... .......... .......... 10%  207M 21s
#   1200K .......... .......... .......... .......... .......... 10% 17,4M 20s
#   1250K .......... .......... .......... .......... .......... 11% 8,34M 19s
#   1300K .......... .......... .......... .......... .......... 11%  253K 20s
#   1350K .......... .......... .......... .......... .......... 11% 15,1M 19s
#   1400K .......... .......... .......... .......... .......... 12% 6,95M 18s
#   1450K .......... .......... .......... .......... .......... 12%  256K 19s
#   1500K .......... .......... .......... .......... .......... 13% 6,86M 18s
#   1550K .......... .......... .......... .......... .......... 13% 61,1M 18s
#   1600K .......... .......... .......... .......... .......... 14%  253K 18s
#   1650K .......... .......... .......... .......... .......... 14% 13,6M 18s
#   1700K .......... .......... .......... .......... .......... 14% 10,7M 17s
#   1750K .......... .......... .......... .......... .......... 15%  256K 18s
#   1800K .......... .......... .......... .......... .......... 15% 9,87M 17s
#   1850K .......... .......... .......... .......... .......... 16% 10,3M 17s
#   1900K .......... .......... .......... .......... .......... 16%  252K 17s
#   1950K .......... .......... .......... .......... .......... 17%  239K 17s
#   2000K .......... .......... .......... .......... .......... 17%  123M 17s
#   2050K .......... .......... .......... .......... .......... 17%  227M 16s
#   2100K .......... .......... .......... .......... .......... 18%  215M 16s
#   2150K .......... .......... .......... .......... .......... 18%  250K 16s
#   2200K .......... .......... .......... .......... .......... 19% 8,70M 16s
#   2250K .......... .......... .......... .......... .......... 19%  254K 16s
#   2300K .......... .......... .......... .......... .......... 20% 6,86M 16s
#   2350K .......... .......... .......... .......... .......... 20%  305K 16s
#   2400K .......... .......... .......... .......... .......... 20% 1,88M 16s
#   2450K .......... .......... .......... .......... .......... 21% 85,0M 15s
#   2500K .......... .......... .......... .......... .......... 21%  130K 16s
#   2550K .......... .......... .......... .......... .......... 22%  142M 16s
#   2600K .......... .......... .......... .......... .......... 22% 84,9M 16s
#   2650K .......... .......... .......... .......... .......... 23% 4,37M 15s
#   2700K .......... .......... .......... .......... .......... 23%  237K 16s
#   2750K .......... .......... .......... .......... .......... 23% 12,4M 15s
#   2800K .......... .......... .......... .......... .......... 24%  236K 16s
#   2850K .......... .......... .......... .......... .......... 24% 10,2M 15s
#   2900K .......... .......... .......... .......... .......... 25%  251K 16s
#   2950K .......... .......... .......... .......... .......... 25% 9,97M 15s
#   3000K .......... .......... .......... .......... .......... 26%  247K 15s
#   3050K .......... .......... .......... .......... .......... 26% 25,7M 15s
#   3100K .......... .......... .......... .......... .......... 26%  248K 15s
#   3150K .......... .......... .......... .......... .......... 27% 14,3M 15s
#   3200K .......... .......... .......... .......... .......... 27%  280K 15s
#   3250K .......... .......... .......... .......... .......... 28% 12,3M 15s
#   3300K .......... .......... .......... .......... .......... 28%  223K 15s
#   3350K .......... .......... .......... .......... .......... 29% 9,94M 15s
#   3400K .......... .......... .......... .......... .......... 29%  251K 15s
#   3450K .......... .......... .......... .......... .......... 29% 8,53M 15s
#   3500K .......... .......... .......... .......... .......... 30%  254K 15s
#   3550K .......... .......... .......... .......... .......... 30% 9,83M 15s
#   3600K .......... .......... .......... .......... .......... 31%  247K 15s
#   3650K .......... .......... .......... .......... .......... 31% 8,00M 14s
#   3700K .......... .......... .......... .......... .......... 32%  249K 15s
#   3750K .......... .......... .......... .......... .......... 32% 8,59M 14s
#   3800K .......... .......... .......... .......... .......... 32% 21,6M 14s
#   3850K .......... .......... .......... .......... .......... 33%  256K 14s
#   3900K .......... .......... .......... .......... .......... 33% 8,08M 14s
#   3950K .......... .......... .......... .......... .......... 34%  250K 14s
#   4000K .......... .......... .......... .......... .......... 34% 9,16M 14s
#   4050K .......... .......... .......... .......... .......... 35%  249K 14s
#   4100K .......... .......... .......... .......... .......... 35% 53,6M 14s
#   4150K .......... .......... .......... .......... .......... 35%  251K 14s
#   4200K .......... .......... .......... .......... .......... 36% 8,37M 13s
#   4250K .......... .......... .......... .......... .......... 36%  252K 14s
#   4300K .......... .......... .......... .......... .......... 37% 5,87M 13s
#   4350K .......... .......... .......... .......... .......... 37%  255K 13s
#   4400K .......... .......... .......... .......... .......... 38% 11,2M 13s
#   4450K .......... .......... .......... .......... .......... 38%  293K 13s
#   4500K .......... .......... .......... .......... .......... 38% 8,39M 13s
#   4550K .......... .......... .......... .......... .......... 39% 8,70M 13s
#   4600K .......... .......... .......... .......... .......... 39%  220K 13s
#   4650K .......... .......... .......... .......... .......... 40% 17,7M 13s
#   4700K .......... .......... .......... .......... .......... 40%  285K 13s
#   4750K .......... .......... .......... .......... .......... 41% 5,06M 12s
#   4800K .......... .......... .......... .......... .......... 41%  225K 13s
#   4850K .......... .......... .......... .......... .......... 41% 11,1M 12s
#   4900K .......... .......... .......... .......... .......... 42%  254K 12s
#   4950K .......... .......... .......... .......... .......... 42% 10,8M 12s
#   5000K .......... .......... .......... .......... .......... 43%  250K 12s
#   5050K .......... .......... .......... .......... .......... 43% 7,12M 12s
#   5100K .......... .......... .......... .......... .......... 44%  253K 12s
#   5150K .......... .......... .......... .......... .......... 44% 15,1M 12s
#   5200K .......... .......... .......... .......... .......... 44%  248K 12s
#   5250K .......... .......... .......... .......... .......... 45% 10,3M 12s
#   5300K .......... .......... .......... .......... .......... 45% 10,5M 12s
#   5350K .......... .......... .......... .......... .......... 46%  253K 12s
#   5400K .......... .......... .......... .......... .......... 46% 7,20M 11s
#   5450K .......... .......... .......... .......... .......... 47%  250K 11s
#   5500K .......... .......... .......... .......... .......... 47% 3,73M 11s
#   5550K .......... .......... .......... .......... .......... 47%  267K 11s
#   5600K .......... .......... .......... .......... .......... 48% 2,83M 11s
#   5650K .......... .......... .......... .......... .......... 48%  266K 11s
#   5700K .......... .......... .......... .......... .......... 49% 8,57M 11s
#   5750K .......... .......... .......... .......... .......... 49% 7,02M 11s
#   5800K .......... .......... .......... .......... .......... 50%  248K 11s
#   5850K .......... .......... .......... .......... .......... 50% 3,88M 11s
#   5900K .......... .......... .......... .......... .......... 50%  270K 11s
#   5950K .......... .......... .......... .......... .......... 51% 7,31M 10s
#   6000K .......... .......... .......... .......... .......... 51%  255K 10s
#   6050K .......... .......... .......... .......... .......... 52% 5,92M 10s
#   6100K .......... .......... .......... .......... .......... 52% 59,6M 10s
#   6150K .......... .......... .......... .......... .......... 53%  253K 10s
#   6200K .......... .......... .......... .......... .......... 53% 6,17M 10s
#   6250K .......... .......... .......... .......... .......... 53% 10,4M 10s
#   6300K .......... .......... .......... .......... .......... 54%  255K 10s
#   6350K .......... .......... .......... .......... .......... 54% 6,80M 10s
#   6400K .......... .......... .......... .......... .......... 55%  257K 10s
#   6450K .......... .......... .......... .......... .......... 55% 7,84M 9s
#   6500K .......... .......... .......... .......... .......... 56% 7,50M 9s
#   6550K .......... .......... .......... .......... .......... 56%  260K 9s
#   6600K .......... .......... .......... .......... .......... 56% 5,75M 9s
#   6650K .......... .......... .......... .......... .......... 57% 17,1M 9s
#   6700K .......... .......... .......... .......... .......... 57%  254K 9s
#   6750K .......... .......... .......... .......... .......... 58% 8,73M 9s
#   6800K .......... .......... .......... .......... .......... 58% 4,16M 9s
#   6850K .......... .......... .......... .......... .......... 59%  306K 9s
#   6900K .......... .......... .......... .......... .......... 59% 7,77M 8s
#   6950K .......... .......... .......... .......... .......... 59% 3,99M 8s
#   7000K .......... .......... .......... .......... .......... 60%  237K 8s
#   7050K .......... .......... .......... .......... .......... 60% 4,14M 8s
#   7100K .......... .......... .......... .......... .......... 61% 2,23M 8s
#   7150K .......... .......... .......... .......... .......... 61%  282K 8s
#   7200K .......... .......... .......... .......... .......... 62% 2,85M 8s
#   7250K .......... .......... .......... .......... .......... 62% 3,55M 8s
#   7300K .......... .......... .......... .......... .......... 62%  306K 8s
#   7350K .......... .......... .......... .......... .......... 63% 5,04M 8s
#   7400K .......... .......... .......... .......... .......... 63% 4,82M 7s
#   7450K .......... .......... .......... .......... .......... 64% 5,35M 7s
#   7500K .......... .......... .......... .......... .......... 64%  278K 7s
#   7550K .......... .......... .......... .......... .......... 65% 4,93M 7s
#   7600K .......... .......... .......... .......... .......... 65% 4,23M 7s
#   7650K .......... .......... .......... .......... .......... 65%  283K 7s
#   7700K .......... .......... .......... .......... .......... 66% 8,58M 7s
#   7750K .......... .......... .......... .......... .......... 66% 7,27M 7s
#   7800K .......... .......... .......... .......... .......... 67% 7,24M 7s
#   7850K .......... .......... .......... .......... .......... 67%  266K 7s
#   7900K .......... .......... .......... .......... .......... 68% 15,5M 6s
#   7950K .......... .......... .......... .......... .......... 68% 6,01M 6s
#   8000K .......... .......... .......... .......... .......... 68% 9,91M 6s
#   8050K .......... .......... .......... .......... .......... 69%  264K 6s
#   8100K .......... .......... .......... .......... .......... 69% 5,68M 6s
#   8150K .......... .......... .......... .......... .......... 70% 3,85M 6s
#   8200K .......... .......... .......... .......... .......... 70% 17,9M 6s
#   8250K .......... .......... .......... .......... .......... 71% 5,38M 6s
#   8300K .......... .......... .......... .......... .......... 71%  312K 6s
#   8350K .......... .......... .......... .......... .......... 71% 3,44M 5s
#   8400K .......... .......... .......... .......... .......... 72% 6,98M 5s
#   8450K .......... .......... .......... .......... .......... 72% 9,12M 5s
#   8500K .......... .......... .......... .......... .......... 73%  252K 5s
#   8550K .......... .......... .......... .......... .......... 73% 1,29M 5s
#   8600K .......... .......... .......... .......... .......... 74% 3,34M 5s
#   8650K .......... .......... .......... .......... .......... 74% 1,81M 5s
#   8700K .......... .......... .......... .......... .......... 74% 3,62M 5s
#   8750K .......... .......... .......... .......... .......... 75%  527K 5s
#   8800K .......... .......... .......... .......... .......... 75% 1,18M 5s
#   8850K .......... .......... .......... .......... .......... 76% 1,80M 5s
#   8900K .......... .......... .......... .......... .......... 76% 2,38M 4s
#   8950K .......... .......... .......... .......... .......... 77% 6,77M 4s
#   9000K .......... .......... .......... .......... .......... 77%  602K 4s
#   9050K .......... .......... .......... .......... .......... 77% 1,08M 4s
#   9100K .......... .......... .......... .......... .......... 78%  179M 4s
#   9150K .......... .......... .......... .......... .......... 78% 1,53M 4s
#   9200K .......... .......... .......... .......... .......... 79% 3,77M 4s
#   9250K .......... .......... .......... .......... .......... 79%  566K 4s
#   9300K .......... .......... .......... .......... .......... 80% 1,74M 4s
#   9350K .......... .......... .......... .......... .......... 80% 3,06M 4s
#   9400K .......... .......... .......... .......... .......... 80% 1,19M 4s
#   9450K .......... .......... .......... .......... .......... 81% 68,5M 3s
#   9500K .......... .......... .......... .......... .......... 81% 7,70M 3s
#   9550K .......... .......... .......... .......... .......... 82%  559K 3s
#   9600K .......... .......... .......... .......... .......... 82% 1,19M 3s
#   9650K .......... .......... .......... .......... .......... 83% 4,73M 3s
#   9700K .......... .......... .......... .......... .......... 83% 1,23M 3s
#   9750K .......... .......... .......... .......... .......... 83% 60,9M 3s
#   9800K .......... .......... .......... .......... .......... 84%  253K 3s
#   9850K .......... .......... .......... .......... .......... 84%  188M 3s
#   9900K .......... .......... .......... .......... .......... 85%  187M 3s
#   9950K .......... .......... .......... .......... .......... 85%  199M 3s
#  10000K .......... .......... .......... .......... .......... 86%  158M 2s
#  10050K .......... .......... .......... .......... .......... 86%  204M 2s
#  10100K .......... .......... .......... .......... .......... 86%  515K 2s
#  10150K .......... .......... .......... .......... .......... 87% 2,62M 2s
#  10200K .......... .......... .......... .......... .......... 87% 1,14M 2s
#  10250K .......... .......... .......... .......... .......... 88% 5,44M 2s
#  10300K .......... .......... .......... .......... .......... 88%  547K 2s
#  10350K .......... .......... .......... .......... .......... 89% 1,35M 2s
#  10400K .......... .......... .......... .......... .......... 89% 1001K 2s
#  10450K .......... .......... .......... .......... .......... 89% 9,08M 2s
#  10500K .......... .......... .......... .......... .......... 90% 1,93M 2s
#  10550K .......... .......... .......... .......... .......... 90%  426K 2s
#  10600K .......... .......... .......... .......... .......... 91% 3,68M 2s
#  10650K .......... .......... .......... .......... .......... 91% 1,49M 1s
#  10700K .......... .......... .......... .......... .......... 92% 9,66M 1s
#  10750K .......... .......... .......... .......... .......... 92% 1,34M 1s
#  10800K .......... .......... .......... .......... .......... 92%  481K 1s
#  10850K .......... .......... .......... .......... .......... 93% 4,78M 1s
#  10900K .......... .......... .......... .......... .......... 93% 1,69M 1s
#  10950K .......... .......... .......... .......... .......... 94% 3,07M 1s
#  11000K .......... .......... .......... .......... .......... 94%  894K 1s
#  11050K .......... .......... .......... .......... .......... 95%  765K 1s
#  11100K .......... .......... .......... .......... .......... 95% 4,05M 1s
#  11150K .......... .......... .......... .......... .......... 95% 1,61M 1s
#  11200K .......... .......... .......... .......... .......... 96% 1,85M 1s
#  11250K .......... .......... .......... .......... .......... 96% 1,36M 1s
#  11300K .......... .......... .......... .......... .......... 97%  579K 0s
#  11350K .......... .......... .......... .......... .......... 97% 2,97M 0s
#  11400K .......... .......... .......... .......... .......... 98% 1,44M 0s
#  11450K .......... .......... .......... .......... .......... 98% 5,33M 0s
#  11500K .......... .......... .......... .......... .......... 98% 2,85M 0s
#  11550K .......... .......... .......... .......... .......... 99%  580K 0s
#  11600K .......... .......... .......... .......... .......... 99% 1,55M 0s
#  11650K .......... .......... ......                          100%  726K=17s
#
# 2024-12-01 20:53:38 (705 KB/s) - ‘cit-HepTh-abstracts.tar.gz’ saved [11956788/11956788]

# %% [markdown]
# The following script will remove unnecessary lines from the files, and unfolder the folders with data

# %%
# %%bash
# cd ../data
# sed '1,4d' cit-HepTh.txt > temp.txt && mv temp.txt cit-HepTh.txt
# sed '1d' cit-HepTh-dates.txt > temp.txt && mv temp.txt cit-HepTh-dates.txt
# mv cit-HepTh.txt edgelist.txt
# mv cit-HepTh-dates.txt dates.txt

# %%
# %%bash
# cd ../data
# mkdir -p meta_files
#
# for folder in *; do
#   if [ -d "$folder" ] && [ "$folder" != "meta_files" ]; then
#     mv "$folder"/*.* meta_files/
#   fi
# done
#
# find . -type d -empty -not -path "./meta_files" -delete

# %% [markdown]
# Parsing the metadata files. We consider all other information to be too sparse or irrelevant for the research

# %%
paper_features = ('Paper','Date','Title','Authors','Abstract')

# %%
def data_dict_from_file(filename):
    data_dict = dict()
    with open(filename, 'r') as file:
        text = file.read()

        last_comment = text.split("\\\\")[2].strip()

        # Extract key-value pairs using regular expressions and split by newline
        pattern = r"(\S+): (.+)"
        matches = re.findall(pattern, text.split("\\\\")[1], re.MULTILINE)

        # Create a dictionary from the matches
        data_dict = {key.strip(): value.strip() for key, value in matches}
        to_pop = list()
        for key in data_dict.keys():
            if key not in paper_features:
                to_pop.append(key)
        for key in to_pop:
            data_dict.pop(key, None)
        data_dict['Abstract'] = last_comment
        data_dict['Paper'] = int(data_dict['Paper'][7:])
        
        return data_dict

# %%
directory = os.path.join(os.pardir, 'data', 'meta_files')
files = glob.glob(os.path.join(directory, '*'))
dict_list = [data_dict_from_file(file) for file in tqdm(files) if os.path.isfile(file)]
# Out:
# 100%|██████████| 29555/29555 [00:00<00:00, 45886.55it/s]

# %%
full_data_dictionary = {feature: [] for feature in paper_features}

# %%
for d in dict_list:
    for key in paper_features:
        if key not in d.keys():
            d[key] = ''
        full_data_dictionary[key].append(d[key])

# %% [markdown]
# Creating dataframe with everything we need (dates still need some manipulation)

# %%
df = pd.DataFrame.from_dict(full_data_dictionary)
df.head()
# Out:
#      Paper                                           Date  \
# 0  9511170  Thu, 23 Nov 1995 15:22:03 +0000 (GMT)   (8kb)
# 1  9211024            Wed, 4 Nov 1992 14:49 +0200   (7kb)
# 2  9806180         Sun, 21 Jun 1998 21:09:27 GMT   (11kb)
# 3   108199         Mon, 27 Aug 2001 16:34:58 GMT   (10kb)
# 4   110123          Mon, 15 Oct 2001 05:40:51 GMT   (5kb)
#
#                                                Title  \
# 0  Einstein-Infeld-Hoffman method and soliton dyn...
# 1  Discretization of the Superparticle Path Integral
# 2                      Comments on N=2 AdS Orbifolds
# 3  Determinant Line Bundles and Topological Invar...
# 4  Entropy of the three dimensional Schwarzschild...
#
#                                              Authors  \
# 0                                    Jacek Dziarmaga
# 1        J. Grundberg, U. Lindstrom and H. Nordstrom
# 2                                       Sergei Gukov
# 3  A.A. Bytsenko, M.C. Falleiros, A.E. Goncalves ...
# 4
#
#                                             Abstract
# 0  We consider slow motion of a pointlike topolog...
# 1  Requiring that the path integral has the globa...
# 2  We discuss twisted states of AdS orbifolds whi...
# 3  We give some remarks on twisted determinant li...
# 4  We study the three dimensional Schwarzschild-d...

# %% [markdown]
# Let`s fix the dates

# %%
def is_date_format(date_str,form):
    pattern = r'^\d{2}-[A-Z]{3}-\d{4}$'
    if form == 2:
        pattern = r'^\d{2}/\d{2}/\d{2}$'
    if form == 3:
        pattern = r'^(0?\d|[12]\d|3[01])-[a-zA-Z]{3}-\d{4}$'
    if re.match(pattern, date_str):
        return True
    else:
        return False

# %%
for i, row in df.iterrows():
    
    if (row['Paper'] == 9509068):  # no year specified, add it manually
        df.at[i,'Date'] = "2000-09-13"
        continue
        
    date_str = row['Date']
    date_str = date_str.split()
    date_obj = None
    
    if is_date_format(date_str[0],1):
        sp = date_str[0].split('-')
        date_conc = sp[0] + " " + sp[1] + " " + sp[2]
        date_obj = datetime.strptime(date_conc, "%d %b %Y")
        
    elif is_date_format(date_str[0],2): 
        date_obj = datetime.strptime(date_str[0], "%m/%d/%y")
    
    elif is_date_format(date_str[0],3):
        sp = date_str[0].split('-')
        date_conc = '0' + sp[0] + " " + sp[1] + " " + sp[2]
        date_obj = datetime.strptime(date_conc, "%d %b %Y")
    else:
        date_str = date_str[(1 - date_str[0][0].isdigit()):]

        if not date_str[0].isdigit():
            tmp = date_str[0]
            date_str[0] = date_str[1]
            date_str[1] = tmp

        ind = 2
        if date_str[2][-1] == ',':
            date_str[2] = date_str[2][:-1]
        while not date_str[2].isdigit():
            ind += 1
            date_str[2] = date_str[ind]
        if int(date_str[2]) < 100:

            date_str[2] = '19' + date_str[2]

        date_str[1] = date_str[1][:3].upper()
        date_only = date_str[0] +" "+ date_str[1] +" "+ date_str[2]
        date_obj = datetime.strptime(date_only, "%d %b %Y")
        
    formatted_date = date_obj.strftime("%Y-%m-%d")
    df.at[i,'Date'] = formatted_date

# %% [markdown]
# Now let`s turn Authors into a list

# %%
for i, row in df.iterrows():
    string = row['Authors']
    string = string.replace('and',',').replace(' ','').split(',')
    df.at[i,'Authors'] = string

# %% [markdown]
# Also let`s rename columns properly, check our df, and output the result

# %%
df = df.rename(columns={"Paper": "Paper_ID"})

# %%
df.head()
# Out:
#    Paper_ID        Date                                              Title  \
# 0   9511170  1995-11-23  Einstein-Infeld-Hoffman method and soliton dyn...
# 1   9211024  1992-11-04  Discretization of the Superparticle Path Integral
# 2   9806180  1998-06-21                      Comments on N=2 AdS Orbifolds
# 3    108199  2001-08-27  Determinant Line Bundles and Topological Invar...
# 4    110123  2001-10-15  Entropy of the three dimensional Schwarzschild...
#
#                                              Authors  \
# 0                                   [JacekDziarmaga]
# 1            [J.Grundberg, U.Lindstrom, H.Nordstrom]
# 2                                      [SergeiGukov]
# 3  [A.A.Bytsenko, M.C.Falleiros, A.E.Goncalves, Z...
# 4                                                 []
#
#                                             Abstract
# 0  We consider slow motion of a pointlike topolog...
# 1  Requiring that the path integral has the globa...
# 2  We discuss twisted states of AdS orbifolds whi...
# 3  We give some remarks on twisted determinant li...
# 4  We study the three dimensional Schwarzschild-d...

# %%
df.to_csv(os.path.join(os.pardir, "data", "processed.csv"))

# %% [markdown]
# We didn`t need dates file yet, but that time may come

# %% [markdown]
# We noticed that the graph has some incorrect edges: some papers cited other papers that did not yet exist at that time. Let's iterate over all the edges and delete the bad ones.

# %%
import networkx as nx
import sys
scripts_dir = os.path.join(os.path.dirname(os.path.abspath('')), 'scripts')
if not scripts_dir in sys.path:
    sys.path.append(scripts_dir)
from get_graph import get_digraph

# %%
G: nx.DiGraph = get_digraph()

# %%
G.number_of_nodes(), G.number_of_edges()
# Out:
# (27770, 352807)

# %%
edges_to_remove = [e for e in G.edges if not G.nodes[e[0]]['Date'] > G.nodes[e[1]]['Date']]
G.remove_edges_from(edges_to_remove)

# %%
G.number_of_nodes(), G.number_of_edges()
# Out:
# (27770, 351285)

# %% [markdown]
# We decided to remove all nodes not from the largest weak component (stray nodes), since the vast majority of nodes are in the same component

# %%
largest_weak_component = max(nx.weakly_connected_components(G), key=len)
G: nx.DiGraph = G.subgraph(largest_weak_component)

# %%
G.number_of_nodes(), G.number_of_edges()
# Out:
# (27376, 351025)

# %%
with open(os.path.join(os.pardir, 'data', 'edgelist.txt'), 'wb') as edgelist_file:
    nx.write_edgelist(G, edgelist_file, data=False)

# %% [markdown]
# Sinse we decided to remove stray nodes let's remove them from csv dataset too

# %%
df = df[df['Paper_ID'].isin(G.nodes())]
assert df.shape[0] == G.number_of_nodes()
df.to_csv(os.path.join(os.pardir, "data", "processed.csv"), index=False)

# %%
os.remove(os.path.join(os.path.pardir, 'data', 'cit-HepTh-abstracts.tar'))
